# %% [markdown]
# <a href="https://colab.research.google.com/github/ShizukaIkari/LabExtensao2021/blob/main/Titanic_Atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
import seaborn as sns

# %%
# Data url sample
url = 'https://raw.githubusercontent.com/profmoisesomena/escience_and_tools/master/data/titanic_lab_sample.csv'
names = ['pclass','sex','age','sibsp','parch','fare','survived']
dataset = pd.read_csv(url, header = 0, names=names)

pd.pandas.set_option('display.max_columns', None)
print(dataset.describe().transpose())
# Out:
#            count         mean           std     min       25%        50%  \
# pclass    1108.0     2.215704      0.858270  1.0000   1.00000   2.000000
# sex       1108.0     0.387184      0.487326  0.0000   0.00000   0.000000
# age       1108.0    30.089513     13.801245  0.1667  22.00000  30.089513
# sibsp     1108.0     0.518051      0.956431  0.0000   0.00000   0.000000
# parch     1108.0     0.435018      0.913772  0.0000   0.00000   0.000000
# fare      1108.0  5135.653576  27541.433817  0.0000   9.84065  26.000000
# survived  1108.0     0.420578      0.493875  0.0000   0.00000   0.000000
#
#                 75%       max
# pclass     3.000000       3.0
# sex        1.000000       1.0
# age       37.000000      80.0
# sibsp      1.000000       8.0
# parch      1.000000       9.0
# fare      71.837475  262375.0
# survived   1.000000       1.0

# %%
# Analysing data graphically
print(dataset.dtypes)
dataset.hist(figsize=(15,8))
pyplot.show()

df_corr = dataset[names].corr()
f, ax = pyplot.subplots(figsize=(10, 5))
sns.heatmap(df_corr, annot=True, fmt=".3f", linewidths=.7, ax=ax);
# Out:
# pclass        int64
# sex           int64
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# survived      int64
# dtype: object

# %%
array = dataset.values
# Takes all lines and the columns except the target
X = array[:, :6]
y = array[:, 6]
X_train, X_test, Y_train, Y_test = train_test_split(X, y,
                                                                test_size=0.30,
                                                                random_state=42,
                                                                shuffle=True)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions_train = model.predict(X_train)
predictions_validation = model.predict(X_test)
print(sklearn.metrics.accuracy_score(Y_train, predictions_train))
# Out:
# 0.7612903225806451

# %%
print(sklearn.metrics.accuracy_score(Y_test, predictions_validation))
# Out:
# 0.7687687687687688
